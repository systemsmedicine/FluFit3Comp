# %% [markdown]
# # Modeling Influenza A Udorn (H3N2) in the resperatory tract of mice
#
# This notebook plots the results of parameter optimization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14
plt.rcParams['font.size'] = 16
plt.rcParams['font.family'] = 'serif'
plt.rcParams['text.usetex'] = True

import seaborn as sns

# %%
palette = sns.color_palette('viridis', n_colors=7)
palette
# Out:
# [(0.278826, 0.17549, 0.483397),
#  (0.229739, 0.322361, 0.545706),
#  (0.172719, 0.448791, 0.557885),
#  (0.127568, 0.566949, 0.550556),
#  (0.157851, 0.683765, 0.501686),
#  (0.369214, 0.788888, 0.382914),
#  (0.678489, 0.863742, 0.189503)]

# %% [markdown]
# ## Data

# %%
# Data in log scale
df = pd.read_csv('data/viral_load.csv')
df
# Out:
#    Day     nose     stdN  trachea     stdT     lung     stdL
# 0    1  4.12033  0.85892  1.44097  0.47830  1.00111  0.02002
# 1    2  5.07884  0.63485  3.60242  0.58729  2.36263  0.94104
# 2    3  3.94606  0.35477  4.69828  0.69022  3.21023  1.58844
# 3    4  4.51867  0.15560  4.64379  0.90212  4.07119  1.40823
# 4    5  4.48133  0.58506  4.14127  1.15641  2.14238  1.48165
# 5    6  3.67220  0.22407  2.61554  0.36327  4.41157  0.26696
# 6    7  3.23029  0.27386  0.99899  0.02422  1.14127  0.32035
# 7    8  1.16390  0.23029  0.99899  0.01816  0.99444  0.02002

# %%
dfCD8 = pd.read_csv('data/cd8_h3n2.csv')
dfCD8
# Out:
#    Day  Trachea    Lungs
# 0    6     7188  2288802
# 1    8    10614  4685658
# 2   10    10520  1943025
# 3   14     4637  1495088

# %%
parNames=['RSS', 'V0',
          'bet1', 'xi1', 'chi1', 'del1', 'rho1', 'sig1', 'alp1', 'phi1',
          'bet2', 'xi2', 'chi2', 'psi2', 'del2', 'rho2', 'sig2', 'alp2', 'phi2', 'eta2', 'kap2', 'ups2',
          'bet3', 'xi3', 'chi3', 'psi3', 'del3', 'rho3', 'sig3', 'alp3', 'phi3', 'eta3', 'kap3', 'ups3',
          'gam12', 'gam21', 'gam23', 'gam32', 'zet23', 'zet32']

# There's a discrepancy in the name of some parameters
# between the paper and how I handled in the codes,
# here the equivalencies:
# rho -> p
# sig -> c

# %% [markdown]
# ## Functions

# %%
def safeLog10(x, eps=1e-8):
    return np.log10(x + eps)

# %%
def unpack_params(params):
    ii = 2  # skip two first param (RSS and V0)

    # Compartment 1
    bet1, xi1, chi1, del1, rho1, sig1, alp1, phi1 = params[ii:ii+8]
    ii += 8

    # Compartment 2
    bet2, xi2, chi2, psi2, del2, rho2, sig2, alp2, phi2, eta2, kap2, ups2 = params[ii:ii+12]
    ii += 12

    # Compartment 3
    bet3, xi3, chi3, psi3, del3, rho3, sig3, alp3, phi3, eta3, kap3, ups3 = params[ii:ii+12]
    ii += 12

    # Transfer rates
    gam12, gam21, gam23, gam32, zet23, zet32 = params[ii:ii+6]

    return {
        'bet1': bet1, 'xi1': xi1, 'chi1': chi1, 'del1': del1, 'rho1': rho1, 'sig1': sig1, 'alp1': alp1, 'phi1': phi1,
        'bet2': bet2, 'xi2': xi2, 'chi2': chi2, 'psi2': psi2, 'del2': del2, 'rho2': rho2, 'sig2': sig2, 'alp2': alp2,
        'phi2': phi2, 'eta2': eta2, 'kap2': kap2, 'ups2': ups2,
        'bet3': bet3, 'xi3': xi3, 'chi3': chi3, 'psi3': psi3, 'del3': del3, 'rho3': rho3, 'sig3': sig3, 'alp3': alp3,
        'phi3': phi3, 'eta3': eta3, 'kap3': kap3, 'ups3': ups3,
        'gam12': gam12, 'gam21': gam21, 'gam23': gam23, 'gam32': gam32, 'zet23': zet23, 'zet32': zet32
    }

# %%
def AICc_func(RSS, M, N):
    return N*np.log10(RSS/N) + 2*M*N/(N-M-1)

# %% [markdown]
# ## Model 1:
#
# **Nose**:
# $$\dot{U_1} = -\beta_1 U_1 V_1$$
# $$\dot{I_1} = \beta_1 U_1 V_1 - \delta_1 I_1$$
# $$\dot{V_1} = \rho_1 I_1 - \varsigma_1 V_1 - \gamma_{12}V_1 + \gamma_{21}V_2$$
#
# **Trachea**:
# $$\dot{U_2} = -\beta_2 U_2 V_2$$
# $$\dot{I_2} = \beta_2 U_2 V_2 - \delta_2 I_2$$
# $$\dot{V_2} = \rho_2 I_2 - \varsigma_2 V_2 - \gamma_{21}V_2 + \gamma_{12}V_1 - \gamma_{23}V_2 + \gamma_{32}V_3$$
#
# **Lung**:
# $$\dot{U_3} = -\beta_3 U_3 V_3$$
# $$\dot{I_3} = \beta_3 U_3 V_3 - \delta_3 I_3$$
# $$\dot{V_3} = \rho_3 I_3 - \varsigma_3 V_3 - \gamma_{32}V_3 + \gamma_{23}V_2$$

# %%
params = np.loadtxt('data/bestPars_M1.dat')
params = 10**params
for i in range(len(parNames)):
    print(f'{parNames[i]} = {params[i]}')
# Out:
# RSS = 11.669815771506979
# V0 = 31622.776601683792
# bet1 = 2.248966570685464e-06
# xi1 = nan
# chi1 = nan
# del1 = 10.0
# rho1 = 1.0
# sig1 = 4.1999971916042576
# alp1 = nan
# phi1 = nan
# bet2 = 1.1633650164791503e-05
# xi2 = nan
# chi2 = nan
# psi2 = nan
# del2 = 10.0
# rho2 = 1.0
# sig2 = 4.1999971916042576
# alp2 = nan
# phi2 = nan
# eta2 = nan
# kap2 = nan
# ups2 = nan
# bet3 = 6.127255636501847e-07
# xi3 = nan
# chi3 = nan
# psi3 = nan
# del3 = 4.157200779049704
# rho3 = 1.0
# sig3 = 4.1999971916042576
# alp3 = nan
# phi3 = nan
# eta3 = nan
# kap3 = nan
# ups3 = nan
# gam12 = 0.0016203133118264266
# gam21 = 1.0
# gam23 = 0.3023012896994183
# gam32 = 0.2851215215671058
# zet23 = nan
# zet32 = nan

# %%
RSS = params[0]
M = 11
N = 3*df.shape[0]
AICc = AICc_func(RSS, M, N)
print(f"AICc = {AICc}")
# Out:
# AICc = 36.48446619892145

# %%
def model1(y, t, params):
    p = unpack_params(params)
    
    U1, I1, V1, U2, I2, V2, U3, I3, V3 = y

    dU1 = -p['bet1']*U1*V1
    dI1 = p['bet1']*U1*V1 - p['del1']*I1
    dV1 = p['rho1']*I1 - p['sig1']*V1 - p['gam12']*V1 + p['gam21']*V2

    dU2 = -p['bet2']*U2*V2
    dI2 = p['bet2']*U2*V2 - p['del2']*I2
    dV2 = p['rho2']*I2 - p['sig2']*V2 - p['gam21']*V2 + p['gam12']*V1 - p['gam23']*V2 + p['gam32']*V3

    dU3 = -p['bet3']*U3*V3
    dI3 = p['bet3']*U3*V3 - p['del3']*I3
    dV3 = p['rho3']*I3 - p['sig3']*V3 - p['gam32']*V3 + p['gam23']*V2
    
    return [dU1, dI1, dV1, dU2, dI2, dV2, dU3, dI3, dV3]

# %%
U10, U20, U30 = 1e7, 1e7, 1e7
I10, I20, I30 = 0.0, 0.0, 0.0
V10, V20, V30 = params[1], 0.0, 0.0
initState = [U10, I10, V10, U20, I20, V20, U30, I30, V30]
    
timeStep = 0.1
endDay = 10
tt = np.arange(0, endDay, timeStep)

levels = odeint(model1, initState, tt, args=(params,))

UU1 = levels[:,0]
II1 = levels[:,1]
VV1 = levels[:,2]

UU2 = levels[:,3]
II2 = levels[:,4]
VV2 = levels[:,5]

UU3 = levels[:,6]
II3 = levels[:,7]
VV3 = levels[:,8]

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(12,10), facecolor='white')

# Nose
axs[0,0].set_title('Nose')
axs[0,0].plot(tt, safeLog10(VV1), lw=3, color=palette[1])
axs[0,0].errorbar(x=df['Day'], y=df['nose'], yerr=df['stdN'], fmt='o', color=palette[0])
axs[0,0].set_ylim((0))
axs[0,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[0,1].set_title('Nose')
axs[0,1].plot(tt, safeLog10(UU1), lw=3, color=palette[2], label='Healthy cells')
axs[0,1].plot(tt, safeLog10(II1), lw=3, color=palette[4], label='Infected cells')
axs[0,1].set_ylim((0, 9))
axs[0,1].set_ylabel('Cells (log$_{10}$)')
axs[0,1].legend()

# Trachea
axs[1,0].set_title('Trachea')
axs[1,0].plot(tt, safeLog10(VV2), lw=3, color=palette[1])
axs[1,0].errorbar(df['Day'], df['trachea'], yerr=df['stdT'], fmt='o', color=palette[0])
axs[1,0].set_ylim((0))
axs[1,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[1,1].set_title('Trachea')
axs[1,1].plot(tt, safeLog10(UU2), lw=3, color=palette[2], label='Healthy cells')
axs[1,1].plot(tt, safeLog10(II2), lw=3, color=palette[4], label='Infected cells')
axs[1,1].set_ylim((0, 9))
axs[1,1].set_ylabel('Cells (log$_{10}$)')
axs[1,1].legend()

# Lungs
axs[2,0].set_title('Lungs')
axs[2,0].plot(tt, safeLog10(VV3), lw=3, color=palette[1])
axs[2,0].errorbar(df['Day'], df['lung'], yerr=df['stdL'], fmt='o', color=palette[0])
axs[2,0].set_ylim((0))
axs[2,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[2,1].set_title('Lungs')
axs[2,1].plot(tt, safeLog10(UU3), lw=3, color=palette[2], label='Healthy cells')
axs[2,1].plot(tt, safeLog10(II3), lw=3, color=palette[4], label='Infected cells')
axs[2,1].set_ylim((0, 9))
axs[2,1].set_ylabel('Cells (log$_{10}$)')
axs[2,1].legend()

plt.setp(axs, xlim=(0,endDay), xlabel='Days')
plt.tight_layout()

# plt.savefig('M1_fit.pdf')

plt.show()

# %% [markdown]
# ## Model 2:
#
# **Nose**:
# $$\dot{U_1} = -\beta_1 U_1 V_1 - \xi_1 U_1 I_1$$
# $$\dot{I_1} = \beta_1 U_1 V_1 - \delta_1 I_1$$
# $$\dot{V_1} = \rho_1 I_1 - \varsigma_1 V_1 - \gamma_{12}V_1 + \gamma_{21}V_2$$
#
# **Trachea**:
# $$\dot{U_2} = -\beta_2 U_2 V_2 - \xi_2 U_2 I_2$$
# $$\dot{I_2} = \beta_2 U_2 V_2 - \delta_2 I_2$$
# $$\dot{V_2} = \rho_2 I_2 - \varsigma_2 V_2 - \gamma_{21}V_2 + \gamma_{12}V_1 - \gamma_{23}V_2 + \gamma_{32}V_3$$
#
# **Lungs**:
# $$\dot{U_3} = -\beta_3 U_3 V_3 -\xi_3 U_3 I_3$$
# $$\dot{I_3} = \beta_3 U_3 V_3 - \delta_3 I_3$$
# $$\dot{V_3} = \rho_3 I_3 - \varsigma_3 V_3 - \gamma_{32}V_3 + \gamma_{23}V_2$$

# %%
params = np.loadtxt('data/bestPars_M2.dat')
params = 10**params
for i in range(len(parNames)):
    print(f'{parNames[i]} = {params[i]}')
# Out:
# RSS = 11.529832550071827
# V0 = 31622.776601683792
# bet1 = 2.438299221502718e-06
# xi1 = 1.0019960281077883e-08
# chi1 = nan
# del1 = 10.0
# rho1 = 1.0
# sig1 = 4.1999971916042576
# alp1 = nan
# phi1 = nan
# bet2 = 1.1682774659889837e-05
# xi2 = 8.660261382190185e-07
# chi2 = nan
# psi2 = nan
# del2 = 10.0
# rho2 = 1.0
# sig2 = 4.1999971916042576
# alp2 = nan
# phi2 = nan
# eta2 = nan
# kap2 = nan
# ups2 = nan
# bet3 = 9.677763392003763e-07
# xi3 = 1.0171429657614233e-08
# chi3 = nan
# psi3 = nan
# del3 = 5.976913904389366
# rho3 = 1.0
# sig3 = 4.1999971916042576
# alp3 = nan
# phi3 = nan
# eta3 = nan
# kap3 = nan
# ups3 = nan
# gam12 = 0.0012459224174217439
# gam21 = 1.0
# gam23 = 0.3967409235882748
# gam32 = 0.1514921049292491
# zet23 = nan
# zet32 = nan

# %%
RSS = params[0]
M = 14
N = 3*df.shape[0]
AICc = AICc_func(RSS, M, N)
print(f"AICc = {AICc}")
# Out:
# AICc = 67.02534886558813

# %%
def model2(y, t, params):
    p = unpack_params(params)

    U1, I1, R1, V1, U2, I2, R2, V2, U3, I3, R3, V3 = y

    dU1 = -p['bet1']*U1*V1 - p['xi1']*U1*I1
    dI1 = p['bet1']*U1*V1 - p['del1']*I1
    dR1 = p['xi1']*U1*I1
    dV1 = p['rho1']*I1 - p['sig1']*V1 - p['gam12']*V1 + p['gam21']*V2

    dU2 = -p['bet2']*U2*V2 - p['xi2']*U2*I2
    dI2 = p['bet2']*U2*V2 - p['del2']*I2
    dR2 = p['xi2']*U2*I2
    dV2 = p['rho2']*I2 - p['sig2']*V2 - p['gam21']*V2 + p['gam12']*V1 - p['gam23']*V2 + p['gam32']*V3

    dU3 = -p['bet3']*U3*V3 - p['xi3']*U3*I3
    dI3 = p['bet3']*U3*V3 - p['del3']*I3
    dR3 = p['xi3']*U3*I3
    dV3 = p['rho3']*I3 - p['sig3']*V3 - p['gam32']*V3 + p['gam23']*V2

    return [dU1, dI1, dR1, dV1, dU2, dI2, dR2, dV2, dU3, dI3, dR3, dV3]

# %%
U10, U20, U30 = 1e7, 1e7, 1e7
I10, I20, I30 = 0.0, 0.0, 0.0
R10, R20, R30 = 0.0, 0.0, 0.0
V10, V20, V30 = params[1], 0.0, 0.0
initState = [U10, I10, R10, V10, U20, I20, R20, V20, U30, I30, R30, V30]
    
timeStep = 0.1
endDay = 12
tt = np.arange(0, endDay, timeStep)

levels = odeint(model2, initState, tt, args=(params,))

UU1 = levels[:,0]
II1 = levels[:,1]
RR1 = levels[:,2]
VV1 = levels[:,3]

UU2 = levels[:,4]
II2 = levels[:,5]
RR2 = levels[:,6]
VV2 = levels[:,7]

UU3 = levels[:,8]
II3 = levels[:,9]
RR3 = levels[:,10]
VV3 = levels[:,11]

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(12,10), facecolor='white')

# Nose
axs[0,0].set_title('Nose')
axs[0,0].plot(tt, safeLog10(VV1), lw=3, color=palette[1])
axs[0,0].errorbar(x=df['Day'], y=df['nose'], yerr=df['stdN'], fmt='o', color=palette[0])
axs[0,0].set_ylim((0))
axs[0,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[0,1].set_title('Nose')
axs[0,1].plot(tt, safeLog10(UU1), lw=3, color=palette[2], label='Healthy cells')
axs[0,1].plot(tt, safeLog10(II1), lw=3, color=palette[4], label='Infected cells')
axs[0,1].plot(tt, safeLog10(RR1), lw=3, color=palette[3], label='Refractory cells')
axs[0,1].set_ylim((0, 9))
axs[0,1].set_ylabel('Cells (log$_{10}$)')
axs[0,1].legend()

# Trachea
axs[1,0].set_title('Trachea')
axs[1,0].plot(tt, safeLog10(VV2), lw=3, color=palette[1])
axs[1,0].errorbar(df['Day'], df['trachea'], yerr=df['stdT'], fmt='o', color=palette[0])
axs[1,0].set_ylim((0))
axs[1,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[1,1].set_title('Trachea')
axs[1,1].plot(tt, safeLog10(UU2), lw=3, color=palette[2], label='Healthy cells')
axs[1,1].plot(tt, safeLog10(II2), lw=3, color=palette[4], label='Infected cells')
axs[1,1].plot(tt, safeLog10(RR2), lw=3, color=palette[3], label='Refractory cells')
axs[1,1].set_ylim((0, 9))
axs[1,1].set_ylabel('Cells (log$_{10}$)')
axs[1,1].legend()

# Lungs
axs[2,0].set_title('Lungs')
axs[2,0].plot(tt, safeLog10(VV3), lw=3, color=palette[1])
axs[2,0].errorbar(df['Day'], df['lung'], yerr=df['stdL'], fmt='o', color=palette[0])
axs[2,0].set_ylim((0))
axs[2,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[2,1].set_title('Lungs')
axs[2,1].plot(tt, safeLog10(UU3), lw=3, color=palette[2], label='Healthy cells')
axs[2,1].plot(tt, safeLog10(II3), lw=3, color=palette[4], label='Infected cells')
axs[2,1].plot(tt, safeLog10(RR3), lw=3, color=palette[3], label='Refractory cells')
axs[2,1].set_ylim((0, 9))
axs[2,1].set_ylabel('Cells (log$_{10}$)')
axs[2,1].legend()

plt.setp(axs, xlim=(0,endDay), xlabel='Days')
plt.tight_layout()

# plt.savefig('M2_fit.pdf')

plt.show()

# %% [markdown]
# ## Model 3:
#
# **Nose**:
# $$\dot{U_1} = -\beta_1 U_1 V_1 - \xi_1 U_1 F_1$$
# $$\dot{I_1} = \beta_1 U_1 V_1 - \delta_1 I_1$$
# $$\dot{V_1} = \rho_1 I_1 - \varsigma_1 V_1 - \gamma_{12}V_1 + \gamma_{21}V_2$$
# $$\dot{F_1} = \alpha_1 I_1 - \phi_1 F_1$$
#
# **Trachea**:
# $$\dot{U_2} = -\beta_2 U_2 V_2 - \xi_2 U_2 F_2$$
# $$\dot{I_2} = \beta_2 U_2 V_2 - \delta_2 I_2$$
# $$\dot{V_2} = \rho_2 I_2 - \varsigma_2 V_2 - \gamma_{21}V_2 + \gamma_{12}V_1 - \gamma_{23}V_2 + \gamma_{32}V_3$$
# $$\dot{F_2} = \alpha_2 I_2 - \phi_2 F_2$$
#
# **Lungs**:
# $$\dot{U_3} = -\beta_3 U_3 V_3 -\xi_3 U_3 F_3$$
# $$\dot{I_3} = \beta_3 U_3 V_3 - \delta_3 I_3$$
# $$\dot{V_3} = \rho_3 I_3 - \varsigma_3 V_3 - \gamma_{32}V_3 + \gamma_{23}V_2$$
# $$\dot{F_3} = \alpha_3 I_3 - \phi_3 F_3$$

# %%
params = np.loadtxt('data/bestPars_M3.dat', comments='#')
params = 10**params
for i in range(len(parNames)):
    print(f'{parNames[i]} = {params[i]}')
# Out:
# RSS = 7.706479012359871
# V0 = 28101.72632563277
# bet1 = 6.337106414742343e-07
# xi1 = 6.999999355046411
# chi1 = nan
# del1 = 0.4870325639902566
# rho1 = 1.0
# sig1 = 4.1999971916042576
# alp1 = 9.444413645277063e-06
# phi1 = 0.01
# bet2 = 1.0938833198099391e-05
# xi2 = 6.999999355046411
# chi2 = nan
# psi2 = nan
# del2 = 9.50941936085571
# rho2 = 1.0
# sig2 = 4.1999971916042576
# alp2 = 1.980569104157746e-06
# phi2 = 10.0
# eta2 = nan
# kap2 = nan
# ups2 = nan
# bet3 = 4.2389568916063287e-07
# xi3 = 6.999999355046411
# chi3 = nan
# psi3 = nan
# del3 = 4.2442406442956795
# rho3 = 1.0
# sig3 = 4.1999971916042576
# alp3 = 1e-08
# phi3 = 10.0
# eta3 = nan
# kap3 = nan
# ups3 = nan
# gam12 = 0.0014551105851987546
# gam21 = 0.8832588548105771
# gam23 = 0.5727459145375251
# gam32 = 0.002367500067186442
# zet23 = nan
# zet32 = nan

# %%
RSS = params[0]
M = 17
N = 3*df.shape[0]
AICc = AICc_func(RSS, M, N)
print(f"AICc = {AICc}")
# Out:
# AICc = 124.15947419892146

# %%
def model3(y, t, params):
    p = unpack_params(params)
    
    U1, I1, V1, F1, U2, I2, V2, F2, U3, I3, V3, F3 = y

    dU1 = -p['bet1']*U1*V1 - p['xi1']*U1*F1
    dI1 = p['bet1']*U1*V1 - p['del1']*I1
    dV1 = p['rho1']*I1 - p['sig1']*V1 - p['gam12']*V1 + p['gam21']*V2
    dF1 = p['alp1']*I1 - p['phi1']*F1
    
    dU2 = -p['bet2']*U2*V2 - p['xi2']*U2*F2
    dI2 = p['bet2']*U2*V2 - p['del2']*I2
    dV2 = p['rho2']*I2 - p['sig2']*V2 - p['gam21']*V2 + p['gam12']*V1 - p['gam23']*V2 + p['gam32']*V3
    dF2 = p['alp2']*I2 - p['phi2']*F2
    
    dU3 = -p['bet3']*U3*V3 - p['xi3']*U3*F3
    dI3 = p['bet3']*U3*V3 - p['del3']*I3
    dV3 = p['rho3']*I3 - p['sig3']*V3 - p['gam32']*V3 + p['gam23']*V2
    dF3 = p['alp3']*I3 - p['phi3']*F3
    
    return [dU1, dI1, dV1, dF1, dU2, dI2, dV2, dF2, dU3, dI3, dV3, dF3]

# %%
U10, U20, U30 = 1e7, 1e7, 1e7
I10, I20, I30 = 0.0, 0.0, 0.0
V10, V20, V30 = params[1], 0.0, 0.0
F10, F20, F30 = 0.0, 0.0, 0.0
initState = [U10, I10, V10, F10, U20, I20, V20, F20, U30, I30, V30, F30]
    
timeStep = 0.1
endDay = 10
tt = np.arange(0, endDay, timeStep)

levels = odeint(model3, initState, tt, args=(params,))

UU1 = levels[:,0]
II1 = levels[:,1]
VV1 = levels[:,2]
FF1 = levels[:,3]

UU2 = levels[:,4]
II2 = levels[:,5]
VV2 = levels[:,6]
FF2 = levels[:,7]

UU3 = levels[:,8]
II3 = levels[:,9]
VV3 = levels[:,10]
FF3 = levels[:,11]

# %%
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(18,10), facecolor='white')

# Nose
axs[0,0].set_title('Nose')
axs[0,0].plot(tt, safeLog10(VV1), lw=3, color=palette[1])
axs[0,0].errorbar(x=df['Day'], y=df['nose'], yerr=df['stdN'], fmt='o', color=palette[0])
axs[0,0].set_ylim((0))
axs[0,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[0,1].set_title('Nose')
axs[0,1].plot(tt, safeLog10(UU1), lw=3, color=palette[2], label='Healthy cells')
axs[0,1].plot(tt, safeLog10(II1), lw=3, color=palette[4], label='Infected cells')
axs[0,1].set_ylim((0, 9))
axs[0,1].set_ylabel('Cells (log$_{10}$)')
axs[0,1].legend()

axs[0,2].set_title('Nose')
axs[0,2].plot(tt, FF1, lw=3, color=palette[3])
#axs[0,2].set_ylim((0, 9))
axs[0,2].set_ylabel('IFN-I (fold change)')

# Trachea
axs[1,0].set_title('Trachea')
axs[1,0].plot(tt, safeLog10(VV2), lw=3, color=palette[1])
axs[1,0].errorbar(df['Day'], df['trachea'], yerr=df['stdT'], fmt='o', color=palette[0])
axs[1,0].set_ylim((0))
axs[1,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[1,1].set_title('Trachea')
axs[1,1].plot(tt, safeLog10(UU2), lw=3, color=palette[2], label='Healthy cells')
axs[1,1].plot(tt, safeLog10(II2), lw=3, color=palette[4], label='Infected cells')
axs[1,1].set_ylim((0, 9))
axs[1,1].set_ylabel('Cells (log$_{10}$)')
axs[1,1].legend()

axs[1,2].set_title('Trachea')
axs[1,2].plot(tt, FF2, lw=3, color=palette[3])
#axs[1,2].set_ylim((0, 9))
axs[1,2].set_ylabel('IFN-I (fold change)')

# Lungs
axs[2,0].set_title('Lungs')
axs[2,0].plot(tt, safeLog10(VV3), lw=3, color=palette[1])
axs[2,0].errorbar(df['Day'], df['lung'], yerr=df['stdL'], fmt='o', color=palette[0])
axs[2,0].set_ylim((0))
axs[2,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[2,1].set_title('Lungs')
axs[2,1].plot(tt, safeLog10(UU3), lw=3, color=palette[2], label='Healthy cells')
axs[2,1].plot(tt, safeLog10(II3), lw=3, color=palette[4], label='Infected cells')
axs[2,1].set_ylim((0, 9))
axs[2,1].set_ylabel('Cells (log$_{10}$)')
axs[2,1].legend()

axs[2,2].set_title('Lungs')
axs[2,2].plot(tt, FF3, lw=3, color=palette[3])
#axs[2,2].set_ylim((0, 9))
axs[2,2].set_ylabel('IFN-I (fold change)')

plt.setp(axs, xlim=(0,endDay), xlabel='Days')
plt.tight_layout()

# plt.savefig('M3_fit.pdf')

plt.show()

# %% [markdown]
# ## Model 4:
#
# **Nose**:
# $$\dot{U_1} = -\beta_1 U_1 V_1$$
# $$\dot{I_1} = \beta_1 U_1 V_1 - \delta_1 I_1$$
# $$\dot{V_1} = \rho_1 I_1 - \varsigma_1 V_1 - \gamma_{12}V_1 + \gamma_{21}V_2$$
#
# **Trachea**:
# $$\dot{U_2} = -\beta_2 U_2 V_2$$
# $$\dot{I_2} = \beta_2 U_2 V_2 - \delta_2 I_2 - \psi_2 I_2 T_2$$
# $$\dot{V_2} = \rho_2 I_2 - \varsigma_2 V_2 - \gamma_{21}V_2 + \gamma_{12}V_1 - \gamma_{23}V_2 + \gamma_{32}V_3$$
# $$\dot{T_2} = \eta_2 T_2 \left( \frac{V_2^2}{V_2^2 + \kappa_2^2} \right) - \upsilon_2 T_2 + \upsilon_2 T_0 - \zeta_{23} T_2 + \zeta_{32} T_3$$
#
# **Lungs**:
# $$\dot{U_3} = -\beta_3 U_3 V_3$$
# $$\dot{I_3} = \beta_3 U_3 V_3 - \delta_3 I_3 - \psi_3 I_3 T_3$$
# $$\dot{V_3} = \rho_3 I_3 - \varsigma_3 V_3 - \gamma_{32}V_3 + \gamma_{23}V_2$$
# $$\dot{T_3} = \eta_3 T_3 \left( \frac{V_3^2}{V_3^2 + \kappa_3^2} \right) - \upsilon_3 T_3 + \upsilon_3 T_0 - \zeta_{32} T_3 + \zeta_{23} T_2$$

# %%
params = np.loadtxt('data/bestPars_M4.dat', comments='#')
params = 10**params
for i in range(len(parNames)):
    print(f'{parNames[i]} = {params[i]}')
# Out:
# RSS = 11.161305615050887
# V0 = 31345.557612747627
# bet1 = 2.321726187741618e-06
# xi1 = nan
# chi1 = nan
# del1 = 9.960519728429091
# rho1 = 1.0
# sig1 = 4.1999971916042576
# alp1 = nan
# phi1 = nan
# bet2 = 1.0186945905891695e-05
# xi2 = nan
# chi2 = nan
# psi2 = 3.840157174056888e-05
# del2 = 8.597298385278707
# rho2 = 1.0
# sig2 = 4.1999971916042576
# alp2 = nan
# phi2 = nan
# eta2 = 1.3966159577915045
# kap2 = 100.0
# ups2 = 0.01
# bet3 = 8.504523783121827e-07
# xi3 = 4.6795490088932094e-08
# chi3 = nan
# psi3 = 1e-08
# del3 = 4.498699660245819
# rho3 = 1.0
# sig3 = 4.1999971916042576
# alp3 = nan
# phi3 = nan
# eta3 = 4.273739039426652
# kap3 = 100000.0
# ups3 = 0.01
# gam12 = 0.001781611469920879
# gam21 = 0.9074631534225279
# gam23 = 0.39781852242101723
# gam32 = 0.8882700108288735
# zet23 = 0.6137874439983536
# zet32 = 0.02762988008106858

# %%
RSS = params[0]
M = 17
N = 3*df.shape[0]
AICc = AICc_func(RSS, M, N)
print(f"AICc = {AICc}")
# Out:
# AICc = 128.02009019892145

# %%
def model4(y, t, params):
    p = unpack_params(params)

    T20 = 2e2
    T30 = 2e5

    U1, I1, V1, U2, I2, V2, T2, U3, I3, V3, T3 = y

    dU1 = -p['bet1']*U1*V1
    dI1 = p['bet1']*U1*V1 - p['del1']*I1
    dV1 = p['rho1']*I1 - p['sig1']*V1 - p['gam12']*V1 + p['gam21']*V2
    
    dU2 = -p['bet2']*U2*V2
    dI2 = p['bet2']*U2*V2 - p['psi2']*I2*T2 - p['del2']*I2
    dV2 = p['rho2']*I2 - p['sig2']*V2 - p['gam21']*V2 + p['gam12']*V1 - p['gam23']*V2 + p['gam32']*V3
    dT2 = p['eta2']*T2*(V2**2/(V2**2 + p['kap2']**2)) - p['ups2']*T2 + p['ups2']*T30 - p['zet23']*T2 + p['zet32']*T3
    
    dU3 = -p['bet3']*U3*V3
    dI3 = p['bet3']*U3*V3 - p['psi3']*I3*T3 - p['del3']*I3
    dV3 = p['rho3']*I3 - p['sig3']*V3 - p['gam32']*V3 + p['gam23']*V2
    dT3 = p['eta3']*T3*(V3**2/(V3**2 + p['kap3']**2)) - p['ups3']*T3 + p['ups3']*T30 - p['zet32']*T3 + p['zet23']*T2

    return [dU1, dI1, dV1, dU2, dI2, dV2, dT2, dU3, dI3, dV3, dT3]

# %%
U10, U20, U30 = 1e7, 1e7, 1e7
I10, I20, I30 = 0.0, 0.0, 0.0
V10, V20, V30 = params[1], 0.0, 0.0
T20, T30 = 2e2, 2e5
initState = [U10, I10, V10, U20, I20, V20, T20, U30, I30, V30, T30]
    
timeStep = 0.1
endDay = 10
tt = np.arange(0, endDay, timeStep)

levels = odeint(model4, initState, tt, args=(params,))

UU1 = levels[:,0]
II1 = levels[:,1]
VV1 = levels[:,2]

UU2 = levels[:,3]
II2 = levels[:,4]
VV2 = levels[:,5]
TT2 = levels[:,6]

UU3 = levels[:,7]
II3 = levels[:,8]
VV3 = levels[:,9]
TT3 = levels[:,10]

# %%
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(18,10), facecolor='white')

# Nose
axs[0,0].set_title('Nose')
axs[0,0].plot(tt, safeLog10(VV1), lw=3, color=palette[1])
axs[0,0].errorbar(x=df['Day'], y=df['nose'], yerr=df['stdN'], fmt='o', color=palette[0])
axs[0,0].set_ylim((0))
axs[0,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[0,1].set_title('Nose')
axs[0,1].plot(tt, safeLog10(UU1), lw=3, color=palette[2], label='Healthy cells')
axs[0,1].plot(tt, safeLog10(II1), lw=3, color=palette[4], label='Infected cells')
axs[0,1].set_ylim((0, 9))
axs[0,1].set_ylabel('Cells (log$_{10}$)')
axs[0,1].legend()

fig.delaxes(axs[0,2])

# Trachea
axs[1,0].set_title('Trachea')
axs[1,0].plot(tt, safeLog10(VV2), lw=3, color=palette[1])
axs[1,0].errorbar(df['Day'], df['trachea'], yerr=df['stdT'], fmt='o', color=palette[0])
axs[1,0].set_ylim((0))
axs[1,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[1,1].set_title('Trachea')
axs[1,1].plot(tt, safeLog10(UU2), lw=3, color=palette[2], label='Healthy cells')
axs[1,1].plot(tt, safeLog10(II2), lw=3, color=palette[4], label='Infected cells')
axs[1,1].set_ylim((0, 9))
axs[1,1].set_ylabel('Cells (log$_{10}$)')
axs[1,1].legend()

axs[1,2].set_title('Trachea')
axs[1,2].plot(tt, safeLog10(TT2), lw=3, color=palette[5])
#axs[1,2].set_ylim((0, 9))
axs[1,2].set_ylabel('T cells (log$_{10}$)')

# Lungs
axs[2,0].set_title('Lungs')
axs[2,0].plot(tt, safeLog10(VV3), lw=3, color=palette[1])
axs[2,0].errorbar(df['Day'], df['lung'], yerr=df['stdL'], fmt='o', color=palette[0])
axs[2,0].set_ylim((0))
axs[2,0].set_ylabel('Viral load (log$_{10}$ PFU)')

axs[2,1].set_title('Lungs')
axs[2,1].plot(tt, safeLog10(UU3), lw=3, color=palette[2], label='Healthy cells')
axs[2,1].plot(tt, safeLog10(II3), lw=3, color=palette[4], label='Infected cells')
axs[2,1].set_ylim((0, 9))
axs[2,1].set_ylabel('Cells (log$_{10}$)')
axs[2,1].legend()

axs[2,2].set_title('Lungs')
axs[2,2].plot(tt, safeLog10(TT3), lw=3, color=palette[5])
#axs[2,2].set_ylim((0, 9))
axs[2,2].set_ylabel('T cells (log$_{10}$)')

plt.setp(axs, xlim=(0,endDay), xlabel='Days')
plt.tight_layout()

# plt.savefig('M4_fit.pdf')

plt.show()

# %% [markdown]
# ## Model 5:
# Hereeeeeeeeeeeee
# **Nose**:
# $$\dot{U_1} = -\beta_1 U_1 V_1 - \xi_1 U_1 I_1 + \chi_1 R_1$$
# $$\dot{I_1} = \beta_1 U_1 V_1 - \delta_1 I_1$$
# $$\dot{R_1} = \xi_1 U_1 I_1 - \chi_1 R_1$$
# $$\dot{V_1} = \rho_1 I_1 - \varsigma_1 V_1 - \gamma_{12}V_1 + \gamma_{21}V_2$$
#
# **Trachea**:
# $$\dot{U_2} = -\beta_2 U_2 V_2 - \xi_2 U_2 I_2 + \chi_2 R_2$$
# $$\dot{I_2} = \beta_2 U_2 V_2 - \delta_2 I_2 - \psi_2 I_2 T_2$$
# $$\dot{R_2} = \xi_2 U_2 I_2 - \chi_2 R_2$$
# $$\dot{V_2} = \rho_2 I_2 - \varsigma_2 V_2 - \gamma_{21}V_2 + \gamma_{12}V_1 - \gamma_{23}V_2 + \gamma_{32}V_3$$
# $$\dot{T_2} = \eta_2 T_2 \left( \frac{V_2^2}{V_2^2 + \kappa_2^2} \right) - \upsilon_2 T_2 + \upsilon_2 T_0 - \zeta_{23} T_2 + \zeta_{32} T_3$$
#
# **Lungs**:
# $$\dot{U_3} = -\beta_3 U_3 V_3 -\xi_3 U_3 I_3 + \chi_3 R_3$$
# $$\dot{I_3} = \beta_3 U_3 V_3 - \delta_3 I_3 - \psi_3 I_3 T_3$$
# $$\dot{R_3} = \xi_3 U_3 I_3 - \chi_3 R_3$$
# $$\dot{V_3} = \rho_3 I_3 - \varsigma_3 V_3 - \gamma_{32}V_3 + \gamma_{23}V_2$$
# $$\dot{T_3} = \eta_3 T_3 \left( \frac{V_3^2}{V_3^2 + \kappa_3^2} \right) - \upsilon_3 T_3 + \upsilon_3 T_0 - \zeta_{32} T_3 + \zeta_{23} T_2$$

# %%
params = np.loadtxt('data/bestPars_M5.dat', comments='#')
params = 10**params
for i in range(len(parNames)):
    print(f'{parNames[i]} = {params[i]}')
# Out:
# V0 = 5.8187
# bet1 = 8.620481e-08
# xi1 = 1.280821e-05
# chi1 = 0.0
# del1 = 9.203905
# rho1 = 0.01024592
# sig1 = 1.903625
# alp1 = 7.450048e-06
# phi1 = 3.15498e-08
# bet2 = 0.0
# xi2 = 9.992263e-05
# chi2 = 3.647022
# psi2 = 0.02298088
# del2 = 6.563243
# rho2 = 1.0
# sig2 = 1430.733
# alp2 = 0.1414224
# phi2 = 0.02
# eta2 = 1.613231e-05
# kap2 = 0.0001
# ups2 = 0.0
# bet3 = 2.146401e-05
# xi3 = 6.024154
# chi3 = 0.01579636
# psi3 = 1.098689
# del3 = 1.0
# rho3 = 840.2924
# sig3 = 0.1295668
# alp3 = 0.02
# phi3 = 1.789648e-05
# eta3 = 0.9067891
# kap3 = 0.1337114
# ups3 = 0.7496262
# gam12 = 0.0002844547
# gam21 = 0.0001983524
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 params = np.loadtxt('data/bestPars_M6.dat', comments='#')
#       2 for i in range(len(parNames)):
# ----> 3     print(f'{parNames[i]} = {params[i]}')
#
# IndexError: index 35 is out of bounds for axis 0 with size 35

# %%
RSS = params[0]
M = 17
N = 3*df.shape[0]
AICc = AICc_func(RSS, M, N)
print(f"AICc = {AICc}")

# %%
def model5(y, t, params):
    p = unpack_params(params)

    T20 = 1e6
    T30 = 1e6
    
    U1, I1, R1, V1, F1, U2, I2, R2, V2, F2, T2, U3, I3, R3, V3, F3, T3 = y

    dU1 = -p['bet1']*U1*V1 - p['xi1']*U1*F1
    dI1 = p['bet1']*U1*V1 - p['del1']*I1
    dR1 = p['xi1']*U1*F1
    dV1 = p['rho1']*I1 - p['sig1']*V1 - p['gam12']*V1 + p['gam21']*V2
    dF1 = p['alp1']*I1 - p['phi1']*F1
    
    dU2 = -p['bet2']*U2*V2 - p['xi2']*U2*F2
    dI2 = p['bet2']*U2*V2 - p['psi2']*I2*T2 - p['del2']*I2
    dR2 = p['xi2']*U2*F2
    dV2 = p['rho2']*I2 - p['sig2']*V2 - p['gam21']*V2 + p['gam12']*V1 - p['gam23']*V2 + p['gam32']*V3
    dF2 = p['alp2']*I2 - p['phi2']*F2
    dT2 = p['eta2']*T2*(V2**2/(V2**2 + p['kap2']**2)) - p['ups2']*T2 + p['ups2']*T30 - p['zet23']*T2 + p['zet32']*T3
    
    dU3 = -p['bet3']*U3*V3 - p['xi3']*U3*F3
    dI3 = p['bet3']*U3*V3 - p['psi3']*I3*T3 - p['del3']*I3
    dR3 = p['xi3']*U3*F3
    dV3 = p['rho3']*I3 - p['sig3']*V3 - p['gam32']*V3 + p['gam23']*V2
    dF3 = p['alp3']*I3 - p['phi3']*F3
    dT3 = p['eta3']*T3*(V3**2/(V3**2 + p['kap3']**2)) - p['ups3']*T3 + p['ups3']*T30 - p['zet32']*T3 + p['zet23']*T2
    
    return [dU1, dI1, dR1, dV1, dF1, dU2, dI2, dR2, dV2, dF2, dT2, dU3, dI3, dR3, dV3, dF3, dT3]

# %% [raw]
# def model5(y, t, params):
#     p = unpack_params(params)
#
#     T20 = 1e6
#     T30 = 1e6
#
#     dU1, dI1, dR1, dV1, dU2, dI2, dR2, dV2, dT2, dU3, dI3, dR3, dV3, dT3 = y
#
#     dU1 = -p['bet1']*U1*V1 - p['xi1']*U1*I1 + p['chi1']*R1
#     dI1 = p['bet1']*U1*V1 - p['del1']*I1
#     dR1 = p['xi1']*U1*I1 - p['chi1']*R1
#     dV1 = p['rho1']*I1 - p['sig1']*V1 - p['gam12']*V1 + p['gam21']*V2
#
#     dU2 = -p['bet2']*U2*V2 - p['xi2']*U2*I2 + p['chi2']*R2
#     dI2 = p['bet2']*U2*V2 - p['psi2']*I2*T2 - p['del2']*I2
#     dR2 = p['xi2']*U2*I2 - p['chi2']*R2
#     dV2 = p['rho2']*I2 - p['sig2']*V2 - p['gam21']*V2 + p['gam12']*V1 - p['gam23']*V2 + p['gam32']*V3
#     dT2 = p['eta2']*T2*(V2**2/(V2**2 + p['kap2']**2)) - p['ups2']*T2 + p['ups2']*T30 - p['zet23']*T2 + p['zet32']*T3
#
#     dU3 = -p['bet3']*U3*V3 - p['xi3']*U3*I3 + p['chi3']*R3
#     dI3 = p['bet3']*U3*V3 - p['psi3']*I3*T3 - p['del3']*I3
#     dR3 = p['xi3']*U3*I3 - p['chi3']*R3
#     dV3 = p['rho3']*I3 - p['sig3']*V3 - p['gam32']*V3 + p['gam23']*V2
#     dT3 = p['eta3']*T3*(V3**2/(V3**2 + p['kap3']**2)) - p['ups3']*T3 + p['ups3']*T30 - p['zet32']*T3 + p['zet23']*T2
#
#     return [dU1, dI1, dR1, dV1, dU2, dI2, dR2, dV2, dT2, dU3, dI3, dR3, dV3, dT3]

# %% [raw]
# U10, U20, U30 = 5e8, 5e8, 5e8
# I10, I20, I30 = 0.0, 0.0, 0.0
# R10, R20, R30 = 0.0, 0.0, 0.0
# V10, V20, V30 = 10**params[0], 0.0, 0.0
# T20, T30 = 1e6, 1e6
# initState = [U10, I10, R10, V10, U20, I20, R20, V20, T20, U30, I30, R30, V30, T30]
#
# timeStep = 0.01
# endDay = 12
# tt = np.arange(0, endDay+1, timeStep)
#
# levels = odeint(model5, initState, tt, args=(params,))
#
# UU1 = levels[:,0]
# II1 = levels[:,1]
# RR1 = levels[:,2]
# VV1 = levels[:,3]
#
# UU2 = levels[:,4]
# II2 = levels[:,5]
# RR2 = levels[:,6]
# VV2 = levels[:,7]
# TT2 = levels[:,8]
#
# UU3 = levels[:,9]
# II3 = levels[:,10]
# RR3 = levels[:,11]
# VV3 = levels[:,12]
# TT3 = levels[:,13]

# %% [raw]
# fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(24,12), facecolor='white')
#
# # Nose
# axs[0,0].set_title('Nose', fontsize=40)
# axs[0,0].plot(tt, np.log10(VV1), lw=3, color=palette[2])
# axs[0,0].errorbar(x=df['Day'], y=df['nose'], yerr=df['stdN'], fmt='o', color=palette[0], lw=2)
# axs[0,0].set_ylim((0))
# axs[0,0].set_ylabel('Viral load (log$_{10}$ PFU)')
#
# axs[1,0].plot(tt, np.log10(UU1), lw=3, color=palette[1], label='Healthy cells')
# axs[1,0].plot(tt, np.log10(II1), lw=3, color=palette[3], label='Infected cells')
# axs[1,0].plot(tt, np.log10(RR1), lw=3, color=palette[5], label='Refractory cells')
# axs[1,0].set_ylim((0, 9))
# axs[1,0].set_ylabel('Cells (log$_{10}$)')
# axs[1,0].legend()
#
# fig.delaxes(axs[2,0])
#
# # Trachea
# axs[0,1].set_title('Trachea', fontsize=40)
# axs[0,1].plot(tt, np.log10(VV2), lw=3, color=palette[2])
# axs[0,1].errorbar(df['Day'], df['trachea'], yerr=df['stdT'], fmt='o', color=palette[0], lw=2)
# axs[0,1].set_ylim((0))
# axs[0,1].set_ylabel('Viral load (log$_{10}$ PFU)')
#
# axs[1,1].plot(tt, np.log10(UU2), lw=3, color=palette[1], label='Healthy cells')
# axs[1,1].plot(tt, np.log10(II2), lw=3, color=palette[3], label='Infected cells')
# axs[1,1].plot(tt, np.log10(RR2), lw=3, color=palette[5], label='Refractory cells')
# axs[1,1].set_ylim((0, 9))
# axs[1,1].set_ylabel('Cells (log$_{10}$)')
# axs[1,1].legend()
#
# axs[2,1].plot(tt, np.log10(TT2), lw=3, color=palette[4])
# axs[2,1].set_ylim((5,7))
# axs[2,1].set_ylabel('T cells (log$_{10}$)')
#
# # Lungs
# axs[0,2].set_title('Lungs', fontsize=40)
# axs[0,2].plot(tt, np.log10(VV3), lw=3, color=palette[2])
# axs[0,2].errorbar(df['Day'], df['lung'], yerr=df['stdL'], fmt='o', color=palette[0], lw=3)
# axs[0,2].set_ylim((0))
# axs[0,2].set_ylabel('Viral load (log$_{10}$ PFU)')
#
# axs[1,2].plot(tt, np.log10(UU3), lw=3, color=palette[1], label='Healthy cells')
# axs[1,2].plot(tt, np.log10(II3), lw=3, color=palette[3], label='Infected cells')
# axs[1,2].plot(tt, np.log10(RR3), lw=3, color=palette[5], label='Refractory cells')
# axs[1,2].set_ylim((0, 9))
# axs[1,2].set_ylabel('Cells (log$_{10}$)')
# axs[1,2].legend()
#
# rect1 = plt.Rectangle((df8['Day'][0] - 0.5, np.log10(df8['cd8'][0]) - 0.25), 1, 0.5, fc=palette[7], alpha = 0.5)
# rect2 = plt.Rectangle((df8['Day'][1] - 0.5, np.log10(df8['cd8'][1]) - 0.25), 1, 0.5, fc=palette[7], alpha = 0.5)
# rect3 = plt.Rectangle((df8['Day'][2] - 0.5, np.log10(df8['cd8'][2]) - 0.25), 1, 0.5, fc=palette[7], alpha = 0.5)
# rect4 = plt.Rectangle((df8['Day'][3] - 0.5, np.log10(df8['cd8'][3]) - 0.25), 1, 0.5, fc=palette[7], alpha = 0.5)
# axs[2,2].add_patch(rect1)
# axs[2,2].add_patch(rect2)
# axs[2,2].add_patch(rect3)
# axs[2,2].add_patch(rect4)
# axs[2,2].scatter(x=df8['Day'], y=np.log10(df8['cd8']), color=palette[6], marker='x', s=100, lw=3)
# axs[2,2].plot(tt, np.log10(TT3), lw=3, color=palette[4])
# axs[2,2].set_ylim((5,7))
# axs[2,2].set_ylabel('T cells (log$_{10}$)')
#
# plt.setp(axs, xlim=(0,endDay+1), xlabel='Days')
#
# plt.savefig('model5_fit.pdf')
#
# plt.show()

# %% [raw]
# def model4(y, t, params):
#     p = unpack_params(params)
#
#     T20 = 1e6
#     T30 = 1e6
#
#     U1, I1, R1, V1, F1, U2, I2, R2, V2, F2, T2, U3, I3, R3, V3, F3, T3 = y
#
#     dU1 = -p['bet1']*U1*V1 - p['xi1']*U1*F1
#     dI1 = p['bet1']*U1*V1 - p['del1']*I1
#     dR1 = p['xi1']*U1*F1
#     dV1 = p['rho1']*I1 - p['sig1']*V1 - p['gam12']*V1 + p['gam21']*V2
#     dF1 = p['alp1']*I1 - p['phi1']*F1
#
#     dU2 = -p['bet2']*U2*V2 - p['xi2']*U2*F2
#     dI2 = p['bet2']*U2*V2 - p['psi2']*I2*T2 - p['del2']*I2
#     dR2 = p['xi2']*U2*F2
#     dV2 = p['rho2']*I2 - p['sig2']*V2 - p['gam21']*V2 + p['gam12']*V1 - p['gam23']*V2 + p['gam32']*V3
#     dF2 = p['alp2']*I2 - p['phi2']*F2
#     dT2 = p['eta2']*T2*(V2**2/(V2**2 + p['kap2']**2)) - p['ups2']*T2 + p['ups2']*T30 - p['zet23']*T2 + p['zet32']*T3
#
#     dU3 = -p['bet3']*U3*V3 - p['xi3']*U3*F3
#     dI3 = p['bet3']*U3*V3 - p['psi3']*I3*T3 - p['del3']*I3
#     dR3 = p['xi3']*U3*F3
#     dV3 = p['rho3']*I3 - p['sig3']*V3 - p['gam32']*V3 + p['gam23']*V2
#     dF3 = p['alp3']*I3 - p['phi3']*F3
#     dT3 = p['eta3']*T3*(V3**2/(V3**2 + p['kap3']**2)) - p['ups3']*T3 + p['ups3']*T30 - p['zet32']*T3 + p['zet23']*T2
#
#     return [dU1, dI1, dR1, dV1, dF1, dU2, dI2, dR2, dV2, dF2, dT2, dU3, dI3, dR3, dV3, dF3, dT3]
